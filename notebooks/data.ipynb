# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./../data.csv')
df = df.loc[df['location'] == 'Germany']
df.reset_index(drop=True, inplace=True)
total_cases = df['total_cases']
new_cases = df['new_cases']
new_cases_smoothed = df['new_cases_smoothed'][750:]
new_cases_smoothed.reset_index(drop=True, inplace=True)

# %%
plt.plot(new_cases_smoothed)
