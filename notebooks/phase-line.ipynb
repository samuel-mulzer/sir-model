# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
beta = 2
gamma = 0.1
n = 1

f = lambda i: beta * i * (n-i) - gamma * i

limit = -1,2
i = np.arange(limit[0], limit[1], 0.1)
di = f(i)

plt.plot(i,di, '-k')
plt.plot([limit[0], limit[1]],[0,0], '-k')
plt.show()
